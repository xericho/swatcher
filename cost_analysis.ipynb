# %%
import pandas as pd

# %%
df = pd.read_csv('trips/Brian_Wedding.csv')
datetimes = df.query_datetime.unique()

# %%
df[df.query_datetime == datetimes[0]]
# Out:
#          query_datetime returnOrDepart     flight departTime returnTime  \
# 0   2022-03-13 19:34:46         depart       2465     6:35AM    10:10AM
# 1   2022-03-13 19:34:46         depart        829     6:35AM    10:10AM
# 2   2022-03-13 19:34:46         depart  1048/1049     6:35AM    10:10AM
# 3   2022-03-13 19:34:46         depart        136     6:35AM    10:10AM
# 4   2022-03-13 19:34:46         depart  2956/2698     6:35AM    10:10AM
# 5   2022-03-13 19:34:46         depart       3261     6:35AM    10:10AM
# 6   2022-03-13 19:34:46         depart  1309/2151     6:35AM    10:10AM
# 7   2022-03-13 19:34:46         depart        244     6:35AM    10:10AM
# 8   2022-03-13 19:34:46         depart       2741     6:35AM    10:10AM
# 9   2022-03-13 19:34:46         depart        462     6:35AM    10:10AM
# 10  2022-03-13 19:34:46         depart        405     6:35AM    10:10AM
# 11  2022-03-13 19:34:46         depart  2918/3203     6:35AM    10:10AM
# ...
